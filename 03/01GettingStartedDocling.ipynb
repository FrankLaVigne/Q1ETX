# %% [markdown]
# # 3. Document Reality & Ingestion with Docling

# %% [markdown]
# ## Load Variables

# %%
import sys
sys.path.insert(0, "..")
from config import API_KEY as key, ENDPOINT_BASE as endpoint_base

# %% [markdown]
# ## Install Docling

# %%
! pip install docling -q

# %% [markdown]
# ## Conver a PDF to Markdown

# %%
from docling.document_converter import DocumentConverter
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat
from docling.document_converter import PdfFormatOption

source = "../docs/Basic-Fantasy-RPG-Rules-r142.pdf"

# Create PDF pipeline options
pdf_options = PdfPipelineOptions()
pdf_options.do_ocr = False  # 👈 Disable OCR

# Configure converter with format options
converter = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pdf_options)
    }
)

doc = converter.convert(source).document

markdown_content = doc.export_to_markdown()
output_path = "Basic-Fantasy-RPG-Rules-r142.md"

with open(output_path, "w", encoding="utf-8") as f:
    f.write(markdown_content)

print(f"Saved to {output_path}")
# Out:
# 2026-02-12 13:04:10,985 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-02-12 13:04:11,184 - INFO - Going to convert document batch...
# 2026-02-12 13:04:11,185 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 75463f421d05cb4304e1f714cf00d35d
# 2026-02-12 13:04:11,190 - INFO - Loading plugin 'docling_defaults'
# 2026-02-12 13:04:11,192 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2026-02-12 13:04:11,198 - INFO - Loading plugin 'docling_defaults'
# 2026-02-12 13:04:11,202 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-02-12 13:04:11,232 - INFO - Accelerator device: 'cuda:0'
# /home/frank/jupyterlab/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(
# 2026-02-12 13:04:13,272 - INFO - Accelerator device: 'cuda:0'
# 2026-02-12 13:04:14,830 - INFO - Processing document Basic-Fantasy-RPG-Rules-r142.pdf
# 2026-02-12 13:05:34,016 - INFO - Finished converting document Basic-Fantasy-RPG-Rules-r142.pdf in 83.12 sec.
# Saved to Basic-Fantasy-RPG-Rules-r142.md

# %%
markdown_content = doc.export_to_markdown()
output_path = "Basic-Fantasy-RPG-Rules-r142.md"

with open(output_path, "w", encoding="utf-8") as f:
    f.write(markdown_content)

print(f"Saved to {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 markdown_content = doc.export_to_markdown()
#       2 output_path = "Basic-Fantasy-RPG-Rules-r142.md"
#       4 with open(output_path, "w", encoding="utf-8") as f:
#
# NameError: name 'doc' is not defined
